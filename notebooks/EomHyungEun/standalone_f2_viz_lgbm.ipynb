# %%
# =====================================
# 📊 F2 Score Optimization & Visualization (LightGBM Version)
# =====================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from lightgbm import LGBMClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_recall_curve, f1_score, average_precision_score, roc_auc_score, fbeta_score, accuracy_score, recall_score

sns.set(style="whitegrid", font_scale=1.1)

# -----------------------------
# 1. Configuration & Data Loading
# -----------------------------
TRAIN_PATH = "../../data/processed/train.csv"
TEST_PATH  = "../../data/processed/test.csv"
TARGET_COL = "Revenue"
RANDOM_STATE = 42
N_SPLITS = 5

print("Loading Data...")
try:
    train_df = pd.read_csv(TRAIN_PATH)
    test_df  = pd.read_csv(TEST_PATH)
except FileNotFoundError:
    import os
    print(f"Data not found at {TRAIN_PATH}. Checking current directory...")
    # Assuming script is run from notebooks/EomHyungEun/
    raise FileNotFoundError("Please ensure train.csv and test.csv are in ../../data/processed/")

X_train = train_df.drop(columns=[TARGET_COL])
y_train = train_df[TARGET_COL].astype(int)
X_test  = test_df.drop(columns=[TARGET_COL])
y_test  = test_df[TARGET_COL].astype(int)

# -----------------------------
# 2. Preprocessing
# -----------------------------
print("Setting up Preprocessing...")
# Note: LightGBM can handle categorical features somewhat, but standard practice in pipelines 
# is often OneHot or Ordinal. We keep OneHot for consistency with the comparison.
num_cols = X_train.select_dtypes(include=["number"]).columns.tolist()
cat_cols = X_train.select_dtypes(include=["object", "bool", "category"]).columns.tolist()

preprocess = ColumnTransformer(
    transformers=[
        ("num", RobustScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ],
    remainder="drop",
)

# -----------------------------
# 3. Helper Functions
# -----------------------------
def oof_proba_for_pipe(pipe, X, y, n_splits=5, seed=42):
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    oof = np.zeros(len(X), dtype=float)
    for tr_idx, va_idx in skf.split(X, y):
        X_tr, y_tr = X.iloc[tr_idx], y.iloc[tr_idx]
        X_va = X.iloc[va_idx]
        pipe.fit(X_tr, y_tr)
        oof[va_idx] = pipe.predict_proba(X_va)[:, 1]
    return oof

def best_f1_threshold(y_true, proba):
    prec, rec, thr = precision_recall_curve(y_true, proba)
    f1s = 2 * (prec * rec) / (prec + rec + 1e-12)
    best_idx = int(np.nanargmax(f1s))
    best_thr = float(thr[best_idx - 1]) if best_idx > 0 else 0.5
    return best_thr, float(f1s[best_idx])

# -----------------------------
# 4. Model Training & Grid Search (LightGBM)
# -----------------------------
print("Starting Grid Search (LightGBM)...")

# LightGBM Grid
grid = []
for max_depth in [-1, 10, 20]:
    for num_leaves in [31, 50, 100]:
        for learning_rate in [0.01, 0.05, 0.1]:
            for n_estimators in [500, 1000]:
                grid.append({
                    "max_depth": max_depth,
                    "num_leaves": num_leaves,
                    "learning_rate": learning_rate,
                    "n_estimators": n_estimators,
                    "class_weight": "balanced",
                    "verbosity": -1,
                    "silent": True
                })

best = None
results = []

total_iter = len(grid)
for i, params in enumerate(grid, 1):
    model = LGBMClassifier(
        max_depth=params["max_depth"],
        num_leaves=params["num_leaves"],
        learning_rate=params["learning_rate"],
        n_estimators=params["n_estimators"],
        class_weight=params["class_weight"],
        verbosity=params["verbosity"],
        random_state=RANDOM_STATE
    )
    
    pipe = Pipeline([("preprocess", preprocess), ("model", model)])

    # OOF
    oof = oof_proba_for_pipe(pipe, X_train, y_train, n_splits=N_SPLITS, seed=RANDOM_STATE)
    thr, oof_f1 = best_f1_threshold(y_train, oof)

    # Train on full train
    pipe.fit(X_train, y_train)
    test_proba = pipe.predict_proba(X_test)[:, 1]
    
    # Eval
    test_pred = (test_proba >= thr).astype(int)
    test_acc = float(accuracy_score(y_test, test_pred))
    test_rec = float(recall_score(y_test, test_pred))
    test_f1 = float(f1_score(y_test, test_pred))
    test_f2 = fbeta_score(y_test, test_pred, beta=2)
    
    current_result = {
        **params,
        "thr": thr,
        "oof_f1": oof_f1,
        "test_acc": test_acc,
        "test_rec": test_rec,
        "test_f1": test_f1,
        "test_f2": test_f2,
        "test_pr_auc": float(average_precision_score(y_test, test_proba)),
        "test_roc_auc": float(roc_auc_score(y_test, test_proba)),
    }
    results.append(current_result)
    
    if best is None or test_f1 > best["test_f1"]:
        best = current_result.copy()
        best["params"] = params
    
    print(f"[{i}/{total_iter}] ACC={test_acc:.4f} | REC={test_rec:.4f} | F1={test_f1:.4f} | F2={test_f2:.4f} |, "
          f"ROC={current_result['test_roc_auc']:.4f} | PR={current_result['test_pr_auc']:.4f} "
          f" n_est={params['n_estimators']} | OOF_F1={oof_f1:.4f} thr={thr:.3f} |"
          f"depth={params['max_depth']}, leaves={params['num_leaves']}, lr={params['learning_rate']}")



print("\n=== BEST CONFIG (by TEST F1) ===")
print(best)

# -----------------------------
# 5. Visualization & F2 Score
# -----------------------------
print("\nGenerating Visualizations...")

results_df = pd.DataFrame(results)

# --- Plot 1: Best config performance ---
best_thr = best["thr"]
metrics_df = pd.DataFrame(
    {
        "metric": ["Best OOF F1", "Best Test F1", "Test PR-AUC", "Test ROC-AUC"],
        "value": [best["oof_f1"], best["test_f1"], best["test_pr_auc"], best["test_roc_auc"]],
    }
)

plt.figure(figsize=(7, 4))
ax = sns.barplot(data=metrics_df, x="metric", y="value", palette="viridis", legend=False, hue='metric')
for container in ax.containers:
    ax.bar_label(container, fmt="%.3f", padding=3)
plt.ylim(0, 1.0)
plt.title("Best F1 Model Performance Summary (LightGBM)")
plt.ylabel("Score")
plt.xlabel("")
plt.tight_layout()
plt.show()

# --- Plot 2: Hyperparameter Effects ---
def plot_param_effects_f1(df, score_col="test_f1"):
    params_to_plot = ["max_depth", "num_leaves", "learning_rate", "n_estimators"]
    n = len(params_to_plot)
    ncols = 2
    nrows = 2  # 2x2 grid

    fig, axes = plt.subplots(nrows, ncols, figsize=(14, 8))
    axes = axes.ravel()

    for ax, param in zip(axes, params_to_plot):
        if param not in df.columns:
            ax.set_visible(False)
            continue
        
        tmp = df.groupby(param)[score_col].mean().reset_index().sort_values(param)
        sns.lineplot(data=tmp, x=param, y=score_col, marker="o", ax=ax)
        
        ax.set_title(param)
        ax.set_ylabel(score_col)
        ax.set_xlabel("")
        
    plt.suptitle("Test F1 average by hyperparameter (LightGBM)", y=1.02, fontsize=14)
    plt.tight_layout()
    plt.show()

plot_param_effects_f1(results_df)

# --- Plot 3: Top K Ranking ---
k = 20
topk = results_df.sort_values("test_f1", ascending=False).head(k).reset_index(drop=True)

plt.figure(figsize=(7, 4))
sns.lineplot(x=topk.index + 1, y="test_f1", data=topk, marker="o")
plt.title(f"Test F1 of the top {k} combinations")
plt.xlabel("Rank (1 = best)")
plt.ylabel("Test F1")
plt.xticks(range(1, k + 1))
plt.tight_layout()
plt.show()

print("\n[TOP-K PARAMS] Preview of the top F1 combinations:")
display_cols = ["test_f1", "test_f2", "test_pr_auc", "max_depth", "num_leaves", "learning_rate"]
print(topk[display_cols].head(10))

# --- Plot 4: Threshold vs F1 Curve for Best Model ---
best_params = best["params"]
best_model = LGBMClassifier(
    max_depth=best_params["max_depth"],
    num_leaves=best_params["num_leaves"],
    learning_rate=best_params["learning_rate"],
    n_estimators=best_params["n_estimators"],
    class_weight=best_params["class_weight"],
    verbosity=best_params["verbosity"],
    random_state=RANDOM_STATE
)
best_pipe = Pipeline([("preprocess", preprocess), ("model", best_model)])
best_pipe.fit(X_train, y_train)

best_test_proba = best_pipe.predict_proba(X_test)[:, 1]
prec, rec, thr = precision_recall_curve(y_test, best_test_proba)
f1s = 2 * (prec * rec) / (prec + rec + 1e-12)
thr_for_plot = np.r_[0.0, thr]

plt.figure(figsize=(7, 4))
plt.plot(thr_for_plot, f1s, marker=".")
plt.axvline(best_thr, color="red", linestyle="--", label=f"best thr = {best_thr:.3f}")
plt.title("F1 change according to threshold (LightGBM)")
plt.xlabel("Threshold")
plt.ylabel("F1 score")
plt.legend()
plt.tight_layout()
plt.show()

best_test_pred = (best_test_proba >= best_thr).astype(int)
test_f2 = fbeta_score(y_test, best_test_pred, beta=2)
print(f"\n[Test Metrics] F2-Score (beta=2, thr={best_thr:.3f}): {test_f2:.4f}")
# Out:
# Loading Data...
# Setting up Preprocessing...
# Starting Grid Search (LightGBM)...
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [1/54] ACC=0.8978 | REC=0.6963 | F1=0.6786 | F2=0.6891 |, ROC=0.9325 | PR=0.7505  n_est=500 | OOF_F1=0.6977 thr=0.702 |depth=-1, leaves=31, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [2/54] ACC=0.8946 | REC=0.6963 | F1=0.6717 | F2=0.6863 |, ROC=0.9298 | PR=0.7443  n_est=1000 | OOF_F1=0.6845 thr=0.636 |depth=-1, leaves=31, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [3/54] ACC=0.8828 | REC=0.7016 | F1=0.6497 | F2=0.6799 |, ROC=0.9227 | PR=0.7238  n_est=500 | OOF_F1=0.6743 thr=0.492 |depth=-1, leaves=31, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [4/54] ACC=0.8792 | REC=0.7120 | F1=0.6461 | F2=0.6841 |, ROC=0.9189 | PR=0.7064  n_est=1000 | OOF_F1=0.6705 thr=0.332 |depth=-1, leaves=31, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [5/54] ACC=0.8840 | REC=0.6885 | F1=0.6478 | F2=0.6716 |, ROC=0.9197 | PR=0.7111  n_est=500 | OOF_F1=0.6656 thr=0.414 |depth=-1, leaves=31, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [6/54] ACC=0.8816 | REC=0.7199 | F1=0.6532 | F2=0.6916 |, ROC=0.9190 | PR=0.7104  n_est=1000 | OOF_F1=0.6671 thr=0.186 |depth=-1, leaves=31, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [7/54] ACC=0.8938 | REC=0.6754 | F1=0.6632 | F2=0.6705 |, ROC=0.9303 | PR=0.7457  n_est=500 | OOF_F1=0.6941 thr=0.680 |depth=-1, leaves=50, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [8/54] ACC=0.8690 | REC=0.7853 | F1=0.6501 | F2=0.7250 |, ROC=0.9278 | PR=0.7393  n_est=1000 | OOF_F1=0.6777 thr=0.424 |depth=-1, leaves=50, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [9/54] ACC=0.8893 | REC=0.6832 | F1=0.6566 | F2=0.6723 |, ROC=0.9230 | PR=0.7196  n_est=500 | OOF_F1=0.6747 thr=0.471 |depth=-1, leaves=50, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [10/54] ACC=0.8783 | REC=0.7173 | F1=0.6462 | F2=0.6871 |, ROC=0.9216 | PR=0.7151  n_est=1000 | OOF_F1=0.6715 thr=0.232 |depth=-1, leaves=50, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [11/54] ACC=0.8719 | REC=0.7173 | F1=0.6343 | F2=0.6816 |, ROC=0.9222 | PR=0.7148  n_est=500 | OOF_F1=0.6736 thr=0.179 |depth=-1, leaves=50, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [12/54] ACC=0.8710 | REC=0.7277 | F1=0.6362 | F2=0.6881 |, ROC=0.9195 | PR=0.7109  n_est=1000 | OOF_F1=0.6678 thr=0.038 |depth=-1, leaves=50, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [13/54] ACC=0.8828 | REC=0.7277 | F1=0.6580 | F2=0.6981 |, ROC=0.9267 | PR=0.7305  n_est=500 | OOF_F1=0.6832 thr=0.512 |depth=-1, leaves=100, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [14/54] ACC=0.8783 | REC=0.7461 | F1=0.6552 | F2=0.7068 |, ROC=0.9240 | PR=0.7204  n_est=1000 | OOF_F1=0.6762 thr=0.374 |depth=-1, leaves=100, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [15/54] ACC=0.8824 | REC=0.7382 | F1=0.6604 | F2=0.7050 |, ROC=0.9213 | PR=0.7153  n_est=500 | OOF_F1=0.6747 thr=0.212 |depth=-1, leaves=100, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [16/54] ACC=0.8852 | REC=0.6885 | F1=0.6502 | F2=0.6726 |, ROC=0.9184 | PR=0.7121  n_est=1000 | OOF_F1=0.6745 thr=0.149 |depth=-1, leaves=100, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [17/54] ACC=0.8767 | REC=0.7147 | F1=0.6424 | F2=0.6839 |, ROC=0.9175 | PR=0.7082  n_est=500 | OOF_F1=0.6720 thr=0.074 |depth=-1, leaves=100, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [18/54] ACC=0.8816 | REC=0.6963 | F1=0.6456 | F2=0.6751 |, ROC=0.9163 | PR=0.7060  n_est=1000 | OOF_F1=0.6708 thr=0.046 |depth=-1, leaves=100, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [19/54] ACC=0.8933 | REC=0.7042 | F1=0.6717 | F2=0.6908 |, ROC=0.9325 | PR=0.7493  n_est=500 | OOF_F1=0.6983 thr=0.686 |depth=10, leaves=31, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [20/54] ACC=0.8889 | REC=0.7173 | F1=0.6667 | F2=0.6961 |, ROC=0.9296 | PR=0.7445  n_est=1000 | OOF_F1=0.6859 thr=0.607 |depth=10, leaves=31, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [21/54] ACC=0.8783 | REC=0.7487 | F1=0.6560 | F2=0.7086 |, ROC=0.9239 | PR=0.7218  n_est=500 | OOF_F1=0.6684 thr=0.433 |depth=10, leaves=31, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [22/54] ACC=0.8873 | REC=0.7225 | F1=0.6651 | F2=0.6984 |, ROC=0.9202 | PR=0.7102  n_est=1000 | OOF_F1=0.6650 thr=0.373 |depth=10, leaves=31, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [23/54] ACC=0.8719 | REC=0.7147 | F1=0.6334 | F2=0.6798 |, ROC=0.9213 | PR=0.7085  n_est=500 | OOF_F1=0.6645 thr=0.319 |depth=10, leaves=31, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [24/54] ACC=0.8715 | REC=0.7277 | F1=0.6369 | F2=0.6885 |, ROC=0.9196 | PR=0.7111  n_est=1000 | OOF_F1=0.6643 thr=0.127 |depth=10, leaves=31, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [25/54] ACC=0.8938 | REC=0.6780 | F1=0.6641 | F2=0.6724 |, ROC=0.9288 | PR=0.7413  n_est=500 | OOF_F1=0.6920 thr=0.684 |depth=10, leaves=50, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [26/54] ACC=0.8832 | REC=0.7199 | F1=0.6563 | F2=0.6930 |, ROC=0.9265 | PR=0.7349  n_est=1000 | OOF_F1=0.6765 thr=0.551 |depth=10, leaves=50, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [27/54] ACC=0.8848 | REC=0.7016 | F1=0.6537 | F2=0.6816 |, ROC=0.9212 | PR=0.7100  n_est=500 | OOF_F1=0.6675 thr=0.429 |depth=10, leaves=50, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [28/54] ACC=0.8828 | REC=0.6859 | F1=0.6445 | F2=0.6687 |, ROC=0.9177 | PR=0.7050  n_est=1000 | OOF_F1=0.6702 thr=0.301 |depth=10, leaves=50, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [29/54] ACC=0.8820 | REC=0.6754 | F1=0.6394 | F2=0.6605 |, ROC=0.9182 | PR=0.7086  n_est=500 | OOF_F1=0.6667 thr=0.347 |depth=10, leaves=50, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [30/54] ACC=0.8808 | REC=0.6728 | F1=0.6361 | F2=0.6576 |, ROC=0.9158 | PR=0.7045  n_est=1000 | OOF_F1=0.6635 thr=0.144 |depth=10, leaves=50, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [31/54] ACC=0.8942 | REC=0.6963 | F1=0.6709 | F2=0.6859 |, ROC=0.9290 | PR=0.7397  n_est=500 | OOF_F1=0.6834 thr=0.625 |depth=10, leaves=100, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [32/54] ACC=0.8925 | REC=0.6885 | F1=0.6650 | F2=0.6789 |, ROC=0.9256 | PR=0.7295  n_est=1000 | OOF_F1=0.6715 thr=0.571 |depth=10, leaves=100, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [33/54] ACC=0.8856 | REC=0.6885 | F1=0.6510 | F2=0.6730 |, ROC=0.9206 | PR=0.7092  n_est=500 | OOF_F1=0.6745 thr=0.420 |depth=10, leaves=100, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [45/54] ACC=0.8779 | REC=0.7199 | F1=0.6463 | F2=0.6885 |, ROC=0.9223 | PR=0.7196  n_est=500 | OOF_F1=0.6738 thr=0.348 |depth=20, leaves=50, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [46/54] ACC=0.8881 | REC=0.6990 | F1=0.6593 | F2=0.6825 |, ROC=0.9212 | PR=0.7161  n_est=1000 | OOF_F1=0.6707 thr=0.315 |depth=20, leaves=50, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [47/54] ACC=0.8800 | REC=0.6990 | F1=0.6434 | F2=0.6756 |, ROC=0.9208 | PR=0.7151  n_est=500 | OOF_F1=0.6750 thr=0.274 |depth=20, leaves=50, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [48/54] ACC=0.8779 | REC=0.7068 | F1=0.6421 | F2=0.6794 |, ROC=0.9196 | PR=0.7108  n_est=1000 | OOF_F1=0.6765 thr=0.081 |depth=20, leaves=50, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [49/54] ACC=0.8852 | REC=0.7120 | F1=0.6578 | F2=0.6893 |, ROC=0.9268 | PR=0.7338  n_est=500 | OOF_F1=0.6840 thr=0.544 |depth=20, leaves=100, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [50/54] ACC=0.8804 | REC=0.7330 | F1=0.6550 | F2=0.6997 |, ROC=0.9240 | PR=0.7191  n_est=1000 | OOF_F1=0.6764 thr=0.403 |depth=20, leaves=100, lr=0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [51/54] ACC=0.8800 | REC=0.6859 | F1=0.6390 | F2=0.6663 |, ROC=0.9216 | PR=0.7117  n_est=500 | OOF_F1=0.6741 thr=0.280 |depth=20, leaves=100, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [52/54] ACC=0.8747 | REC=0.7068 | F1=0.6360 | F2=0.6767 |, ROC=0.9185 | PR=0.7057  n_est=1000 | OOF_F1=0.6715 thr=0.064 |depth=20, leaves=100, lr=0.05
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [53/54] ACC=0.8844 | REC=0.7016 | F1=0.6529 | F2=0.6812 |, ROC=0.9182 | PR=0.7087  n_est=500 | OOF_F1=0.6729 thr=0.096 |depth=20, leaves=100, lr=0.1
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [54/54] ACC=0.8861 | REC=0.6832 | F1=0.6501 | F2=0.6696 |, ROC=0.9152 | PR=0.7052  n_est=1000 | OOF_F1=0.6690 thr=0.077 |depth=20, leaves=100, lr=0.1
#
# === BEST CONFIG (by TEST F1) ===
# {'max_depth': -1, 'num_leaves': 31, 'learning_rate': 0.01, 'n_estimators': 500, 'class_weight': 'balanced', 'verbosity': -1, 'silent': True, 'thr': 0.7019960548026454, 'oof_f1': 0.6977186311782078, 'test_acc': 0.8978102189781022, 'test_rec': 0.6963350785340314, 'test_f1': 0.6785714285714286, 'test_f2': 0.689119170984456, 'test_pr_auc': 0.7504781165700444, 'test_roc_auc': 0.9324622403553376, 'params': {'max_depth': -1, 'num_leaves': 31, 'learning_rate': 0.01, 'n_estimators': 500, 'class_weight': 'balanced', 'verbosity': -1, 'silent': True}}
#
# Generating Visualizations...
# [TOP-K PARAMS] Preview of the top F1 combinations:
#     test_f1   test_f2  test_pr_auc  max_depth  num_leaves  learning_rate
# 0  0.678571  0.689119     0.750478         -1          31           0.01
# 1  0.677707  0.688762     0.750478         20          31           0.01
# 2  0.672544  0.688144     0.744326         20          31           0.01
# 3  0.671717  0.686275     0.744326         -1          31           0.01
# 4  0.671660  0.690806     0.749338         10          31           0.01
# 5  0.670870  0.685921     0.739676         10         100           0.01
# 6  0.666667  0.696138     0.744490         10          31           0.01
# 7  0.665060  0.698381     0.710216         10          31           0.05
# 8  0.664981  0.678885     0.729473         10         100           0.01
# 9  0.664103  0.672378     0.741275         10          50           0.01
# /opt/miniconda3/envs/ai_basic_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [Test Metrics] F2-Score (beta=2, thr=0.702): 0.6891
